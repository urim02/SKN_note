# %%
import warnings
import pandas as pd
import numpy as np
import itertools
from collections import Counter
from kiwipiepy import Kiwi
from kiwipiepy.utils import Stopwords

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

import re
from kiwipiepy import Kiwi
from sqlalchemy import create_engine

from wordcloud import WordCloud
import networkx as nx
import matplotlib.pyplot as plt
from PIL import Image

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # Text data Analysis

# %% [markdown]
# ## Text processing

# %% [markdown]
# ### 토큰화 (Tokenization)
#
# 주어진 코퍼스 내에서 분석 대상이 되는 유의한 단위인 토큰으로 나누는 작업<br>
# <br>
# ex) I like chicken <br>
# -> token: I, like, chicken<br>
#
# - token (토큰): 텍스트를 분석하기 위해 나누는 가장 작은 단위
# - corpus(코퍼스): 자연어 처리와 언어학에서 언어 분석을 위해 컴퓨터에 저장된 대규모의 체계적 자연어 자료 모음
# - 단순히 특수문자 등을 제외하고 공백 기준으로 잘라내는 작업이라고 할 수 없다<br>
# <br>
# > ex) 줄임말, 야민정음, 기타, 36.5, Ph.D, ...

# %% [markdown]
# ### 정제 (Cleaning)
#
# 가지고 있는 단어 집합에서 불필요한 데이터를 제거<br>
# 토큰화 작성 전후로 적용<br>
# <br>
# > ex) 등장 빈도가 적은 단어, 길이가 짧은 단어, ...

# %% [markdown]
# ### 정규화 (Normalization)
#
# 표현방법이 다른 단어를 하나의 단어로 통합<br>
# <br>
# > ex)
# - 대소문자 (APPLE == apple) <br>
# - 어간 / 표제어 (running, ran, runs -> run)<br>
# - 동의어 (USA == US)

# %% [markdown]
# ### 표제어 추출 (Lemmatization)
#
# 단어의 어근을 찾아 추출<br>
# <br>
# > ex) <br>
# - am, are, is -> be
# - went -> go

# %% [markdown]
# ### 불용어 (Stopword)
#
# 가지고 있는 데이터 중 불필요한 토큰을 제거 <br>
# 자주 등장하지만 분석에 큰 도움이 되지 않는 단어<br>
# <br>
# > ex) am, I and, about

# %% [markdown]
# --------------

# %% [markdown]
# ## WordCloud
#
# 데이터의 태그들을 분석하여 중요도나 인기도 등을 고려하여 시각적으로 표시 <br>
# -> 텍스트의 데이터를 시각화하여 단어의 빈도나 중요성을 직관적으로 보여주는 도구

# %% [markdown]
# ## Kiwi 객체
#
# 한국어 형태소 분석을 위한 도구로, _kiwiepy_ 라는 라이브러리에서 제공하는 클래스 <br>
# 형태소 분석, 문장 분리, 띄어쓰기 교정 등의 작업 수행 가능 <br>
# -> 텍스트를 보다 구조적으로 분석하고 처리 가능 <br>
# - 형태소 분석: 텍스트를 형태로 단위로 분리 <br>
# -> 형태소의 품사 정보 제공
# - 사용자 사전 추가: 사용자 정의 단어를 사전에 추가하여 분석에 반영 가능
# - 문장 복원 및 교정: 형태소를 결합하여 문장을 복원하거나 띄어쓰기 교정 가능 <br>
# -> 주로 텍스트 전처리 과정에서 사용됨

# %%
# Kiwi 객체를 생성
kiwi = Kiwi()

# 'kiwi_tokenizer' function
# 'contents': 입력 텍스트, 'Stopwords': 불용어 목록 (optional)
def kiwi_tokenizer(contents, stopwords=None):

    # 'contents'를 Kiwi 객체로 tokenize(단어 분리)하고, 명사(NNP, NNG)만 추출
    tokens = [
        token.form                                          # 각 token의 형태소 반환 (단어 자체)
        for token
        in kiwi.tokenize(contents, stopwords=stopwords)     # Kiwi 객체로 tokenize 실행
        if token.tag in {'NNP', 'NNG'}                      # 추출된 token이 NNP(고유명사) 혹은 NNG(일반명사)일 경우만 핉터링
    ]

    # 최종적으로 명사들로만 구성된 리스트 반환
    return tokens

# %% [markdown]
# ## Practice

# %% [markdown]
# #### 유튜브 댓글 분석

# %%
comments = pd.read_csv('./data/NLP/comments.csv').query('video_id == "JPaubSOSxeM"')

# %%
comments['tokens'] = comments.comments.apply(lambda x: kiwi_tokenizer(x))
comments
# Out:
#          video_id                comments        tokens
# 0     JPaubSOSxeM       와 ㅋㅋㅋ ㄹㅇ 숨막힌다 ㅋㅋㅋ           [숨]
# 1     JPaubSOSxeM  아빠가 세뇌 당함..... ㅋㅋㅋㅋㅋㅋㅋ      [아빠, 세뇌]
# 2     JPaubSOSxeM         아 존나 웃기닼ㅋㅋㅋㅋㅋㅋㅋ            []
# 3     JPaubSOSxeM  여자들아 남자 믿지 말고 외박하지마라..  [여자, 남자, 외박]
# 4     JPaubSOSxeM    이건 사랑이 아니다. 애비를 죽여라,      [사랑, 애비]
# ...           ...                     ...           ...
# 3848  JPaubSOSxeM                      오우            []
# 3849  JPaubSOSxeM                   1등 ^^            []
# 3850  JPaubSOSxeM                      와!            []
# 3851  JPaubSOSxeM                    재밌네요            []
# 3852  JPaubSOSxeM                       오            []
#
# [3853 rows x 3 columns]

# %%
# 빈 dictopnary vocabs를 생성하여 단어와 빈도 저장
vocabs = {}

# comments dataframe의 tokens 열을 list로 변환하고, 모든 토큰을 하나의 튜플로 결합
words = tuple(itertools.chain(*comments.tokens.tolist()))

# 각 단어의 빈도 계산
for word in words:
    # 단어가 이미 vocabs에 존재하는 경우 빈도 +1
    if word in vocabs:
        vocabs[word] += 1
    # 단어가 vocabs에 없는 경우 새로 추가하고 빈도 1로 설정
    else:
        vocabs[word] = 1

# 최종적으로 단어와 빈도 저장한 dictionary vocabs 반환
vocabs
# Out:
# {'숨': 113,
#  '아빠': 196,
#  '세뇌': 2,
#  '여자': 24,
#  '남자': 34,
#  '외박': 37,
#  '사랑': 12,
#  '애비': 3,
#  '아영': 63,
#  '짧대': 5,
#  '아버지': 81,
#  '귀여워': 1,
#  '이번': 101,
#  '레전드': 48,
#  '좀비': 2,
#  '소리': 16,
#  '수정': 87,
#  '대역': 2,
#  '대박': 23,
#  '이야기': 9,
#  '기업': 2,
#  '딸아이': 4,
#  '캐나다': 2,
#  '의심': 15,
#  '엄마': 62,
#  '마누라': 4,
#  '장모': 1,
#  '장인': 1,
#  '구라': 13,
#  '일': 22,
#  '상기': 1,
#  '딸': 154,
#  '관광': 7,
#  '진전': 1,
#  '유투브': 5,
#  '확인': 6,
#  '사위': 1,
#  '사이': 8,
#  '손주': 2,
#  '지금': 13,
#  '사실': 2,
#  '타임': 1,
#  '결국': 5,
#  '할아버지': 3,
#  '장려': 1,
#  '아버님': 56,
#  '선': 6,
#  '대본': 29,
#  '야채': 66,
#  '누나': 10,
#  '뷰티 인사이드': 3,
#  '죈장': 1,
#  '눈물': 8,
#  '돈': 8,
#  '나이': 21,
#  '세상': 20,
#  '평생': 6,
#  '양육': 1,
#  '여행': 12,
#  '시집': 9,
#  '신데렐라': 1,
#  '놀이': 1,
#  '때': 122,
#  '먹버': 1,
#  '남친': 29,
#  '호흡': 7,
#  '아내': 6,
#  '짓': 4,
#  '딸래미': 4,
#  '펜션': 10,
#  '말': 38,
#  '스릴러': 19,
#  '본인': 2,
#  '자연': 7,
#  '사람': 37,
#  '아귀': 1,
#  '연기': 99,
#  '나라': 3,
#  '평균': 1,
#  '외모': 6,
#  '고봉': 1,
#  '중간': 11,
#  '몰입': 33,
#  '급발진': 10,
#  '모습': 7,
#  '인간': 3,
#  '골프채': 2,
#  '낙': 4,
#  '시대': 5,
#  '낚시': 79,
#  '생각': 34,
#  '반추': 1,
#  '물': 8,
#  '뒤': 56,
#  '지리': 15,
#  '느낌': 17,
#  '채널': 38,
#  '인위': 1,
#  '야스오': 2,
#  '말투': 5,
#  '영어': 2,
#  '자막': 3,
#  '한국인': 3,
#  '필수': 2,
#  '개': 119,
#  '영아': 16,
#  '대': 36,
#  '이세돌': 145,
#  '신': 82,
#  '서로': 8,
#  '디스거네': 1,
#  '낚시대': 1,
#  '서': 1,
#  '선생': 3,
#  '결말': 5,
#  '이름': 22,
#  '수정이': 36,
#  '네야': 1,
#  '언니': 9,
#  '사회': 1,
#  '생활': 1,
#  '헬스장': 6,
#  '카운터': 6,
#  '엿': 1,
#  '진심': 16,
#  '구독': 35,
#  '예상': 4,
#  '상황': 18,
#  '극': 8,
#  '영상': 254,
#  '연극': 3,
#  '가짜': 10,
#  '매력': 10,
#  '이부뷴': 1,
#  '보수': 6,
#  '머리': 11,
#  '피': 12,
#  '아부지': 12,
#  '우정': 13,
#  '현': 1,
#  '쌉캐리네': 1,
#  '착각': 12,
#  '마지막': 61,
#  '가평': 5,
#  '친구': 49,
#  '정도': 26,
#  '키': 5,
#  '시야': 1,
#  '마음': 8,
#  '차별': 2,
#  '녀': 8,
#  '거절': 1,
#  '기준': 2,
#  '선물': 4,
#  '처다': 1,
#  '경고': 1,
#  '메시지': 1,
#  '갑': 5,
#  '답': 1,
#  '수': 105,
#  '오마주': 2,
#  '디테일': 52,
#  '창': 35,
#  '방패': 25,
#  '앀': 1,
#  '현웃': 1,
#  '소파': 30,
#  '멸망': 2,
#  '알바': 5,
#  '애애애애': 1,
#  '박': 36,
#  '레웃기네': 1,
#  '역': 25,
#  '퀄리티': 56,
#  '배우': 30,
#  '날': 3,
#  '발전': 1,
#  '고민': 2,
#  '클릭': 3,
#  '감사': 33,
#  '자식': 22,
#  '최고': 67,
#  '방어': 4,
#  '칼': 2,
#  '최소': 3,
#  '이상': 6,
#  '나머지': 1,
#  '티키타카': 27,
#  '개그': 6,
#  '너덜트': 48,
#  '최곸': 1,
#  '분노': 2,
#  '조절': 2,
#  '소거': 1,
#  '기능': 1,
#  '육성': 3,
#  '최근': 5,
#  '동종': 1,
#  '업계': 1,
#  '작품': 10,
#  '건': 2,
#  '숏': 26,
#  '박스': 24,
#  '치킨': 2,
#  '괴성': 1,
#  '값': 1,
#  '결혼': 22,
#  '지려버리넼': 1,
#  '조선시대': 1,
#  '전화': 33,
#  '민폐': 1,
#  '양반': 1,
#  '루어': 1,
#  '릴': 1,
#  '공감': 33,
#  '부계': 16,
#  '통화': 29,
#  '도덕': 1,
#  '책': 1,
#  '전': 45,
#  '집': 33,
#  '망나니': 1,
#  '새벽': 2,
#  '연락': 4,
#  '두절': 1,
#  '반복': 2,
#  '부모': 54,
#  '포기': 2,
#  '부탁': 9,
#  '말씀': 6,
#  '재밋네': 3,
#  '겁나웃끼네': 1,
#  '낮': 6,
#  '인스타': 17,
#  '사필귀정': 1,
#  '안': 3,
#  '당근': 8,
#  '마켓': 5,
#  '롤': 3,
#  '감': 6,
#  '개쩌네': 2,
#  '아이디어': 9,
#  '여자분': 11,
#  '개인': 8,
#  '거짓말': 16,
#  '영통': 4,
#  '시': 6,
#  '완벽': 18,
#  '졸라': 1,
#  '잼': 50,
#  '집착': 8,
#  '앜': 14,
#  '아': 4,
#  '미쳨': 1,
#  '공격': 7,
#  '여친': 3,
#  '가족': 7,
#  '비밀': 5,
#  '계곡': 1,
#  '구독자': 72,
#  '댓글': 20,
#  '캐리': 7,
#  '조회': 12,
#  '알고리즘': 4,
#  '유튜브': 18,
#  '허락': 1,
#  '얘기': 16,
#  '유교': 5,
#  '팬되것어': 1,
#  '씨': 5,
#  '급': 47,
#  '발진': 1,
#  '완전': 4,
#  '신세계': 2,
#  '인과': 1,
#  '응보': 1,
#  '쇼파': 19,
#  '나': 2,
#  '아저씨': 2,
#  '거개': 1,
#  '또래': 1,
#  '사진': 2,
#  '전국': 2,
#  '건강': 13,
#  '바람': 1,
#  '감시하': 1,
#  '구': 2,
#  '소름': 19,
#  '바둑판': 16,
#  '알파고': 109,
#  '경기': 5,
#  '안녕': 2,
#  '미국인': 1,
#  '파주': 1,
#  '근무': 1,
#  '미군': 1,
#  '당시': 2,
#  '봉': 1,
#  '가명': 1,
#  '발음': 2,
#  '오류': 1,
#  '진수': 1,
#  '미': 4,
#  '행복': 4,
#  '정보': 5,
#  '하루': 11,
#  '궁극': 1,
#  '기': 6,
#  '표정': 8,
#  '기대': 21,
#  '푸들': 1,
#  '베프이름이': 1,
#  '시점': 2,
#  '역대': 40,
#  '먹이사슬': 1,
#  '팔로우': 15,
#  '스피커': 3,
#  '폰': 9,
#  '부전': 4,
#  '개연': 1,
#  '밴드': 4,
#  '깨알': 2,
#  '반전': 46,
#  '대사': 23,
#  '킬': 2,
#  '포인트': 8,
#  '부녀': 44,
#  '지간': 23,
#  '신뢰': 42,
#  '진실': 2,
#  '평화': 1,
#  '유지': 6,
#  '공동경비구역': 1,
#  '영화': 30,
#  '대워움': 1,
#  '공수': 7,
#  '교대': 3,
#  '노': 5,
#  '진짜': 49,
#  '드립': 2,
#  '엌': 3,
#  '타협': 7,
#  '기보였네': 1,
#  '다음': 15,
#  '장면': 13,
#  '의표': 1,
#  '표현': 9,
#  '연출': 19,
#  '와중': 13,
#  '바둑': 60,
#  '국': 49,
#  '낚싯대': 22,
#  '처자': 1,
#  '분': 5,
#  '정': 9,
#  '맡': 1,
#  '편의점': 9,
#  '이후': 7,
#  '예술': 5,
#  '길이': 1,
#  '역작': 1,
#  '선덴스': 1,
#  '영화제': 1,
#  '출품': 1,
#  '면': 2,
#  '아카데미': 1,
#  '남우': 1,
#  '주연상': 1,
#  '말빨이쎄셬': 1,
#  '마지맏': 1,
#  '이': 4,
#  '전생': 1,
#  '암행어사': 1,
#  '왤캐': 3,
#  '정보력': 1,
#  '존낭': 1,
#  '겨': 1,
#  '최선': 3,
#  '역습': 2,
#  '암': 5,
#  '입장': 7,
#  '혐오': 1,
#  '관계': 9,
#  '바보': 1,
#  '설정': 5,
#  '적령기': 2,
#  '초중반': 2,
#  '공방전': 9,
#  '입담': 1,
#  '바르셀로나': 1,
#  '처음': 15,
#  '썸': 7,
#  '네일': 6,
#  '조이': 11,
#  '찰떡': 5,
#  '와딘짜존잼': 1,
#  '안끝나안씉낰': 1,
#  '여자친구': 2,
#  '짱': 12,
#  '최종': 1,
#  '실세': 1,
#  '어머니': 22,
#  '가출': 1,
#  '이유': 7,
#  '아닠': 5,
#  '뭐옄': 1,
#  '공방': 9,
#  '살': 3,
#  '발': 5,
#  '화이팅': 3,
#  '강사': 2,
#  '비서': 3,
#  '광고': 10,
#  '재미': 19,
#  '기분': 12,
#  '프리미엄': 2,
#  '킹왕짱': 1,
#  '자녀': 4,
#  '성장': 4,
#  '대처': 1,
#  '계획': 1,
#  '재능': 5,
#  '역할': 11,
#  '이다희': 1,
#  '속초': 2,
#  '잔': 2,
#  '와이프': 5,
#  '연애': 9,
#  '시절': 1,
#  '동해': 1,
#  '바다': 1,
#  '저녁': 5,
#  '공중': 1,
#  '줄': 4,
#  '앞': 25,
#  '어머님': 3,
#  '그때': 1,
#  '명작': 9,
#  '웃곀': 4,
#  '영': 10,
#  '언급': 3,
#  '라이토': 1,
#  '두뇌': 3,
#  '싸움': 19,
#  '퐁고': 2,
#  '인형': 5,
#  '달마': 3,
#  '시안': 3,
#  '내용': 12,
#  '중요': 25,
#  '서스펜스': 7,
#  '피곤': 2,
#  '고개': 4,
#  '빠따': 1,
#  '왘': 2,
#  '이편': 1,
#  '태세': 7,
#  '전환': 11,
#  '중독': 3,
#  '장난': 15,
#  '닉넴': 1,
#  '강태공': 11,
#  '현실': 21,
#  '개오져서': 1,
#  '만유': 1,
#  '하이퍼': 3,
#  '리얼리즘': 3,
#  '개체': 1,
#  '스토킹': 1,
#  '애': 11,
#  '장가': 4,
#  '옆': 4,
#  '너털트': 2,
#  '당사자': 1,
#  '자체': 14,
#  '스트레스': 6,
#  '젋음': 1,
#  '후회': 3,
#  '남': 4,
#  '여': 3,
#  '인생': 3,
#  '약속': 3,
#  '끝': 15,
#  '요새': 2,
#  '대세': 2,
#  '장첸': 3,
#  '여성분': 4,
#  '병풍': 7,
#  '스타일': 3,
#  '램': 2,
#  '방생': 2,
#  '스펙타클': 1,
#  '손': 10,
#  '땀': 6,
#  '쇼미더머니': 1,
#  '뷰': 2,
#  '인사': 1,
#  '머야': 1,
#  '딜': 23,
#  '음악': 3,
#  '옛날': 3,
#  '손자': 2,
#  '진짱': 1,
#  '재미떵': 1,
#  '오디션': 1,
#  '타이밍': 2,
#  '동호회': 2,
#  '여기저기': 2,
#  '신용': 1,
#  '거래': 7,
#  '주인': 2,
#  '최지우': 2,
#  '막내': 1,
#  '동생': 3,
#  '추궁': 1,
#  '위': 7,
#  '강아지': 4,
#  '연출력': 2,
#  '개재밋다': 1,
#  '감정': 4,
#  '지렸': 1,
#  '입문': 1,
#  '기억': 2,
#  '다둘': 1,
#  '킹': 11,
#  '준팍': 3,
#  '성공': 4,
#  '산': 2,
#  '교': 2,
#  '눈': 6,
#  '관여': 1,
#  '신선': 1,
#  '결과': 2,
#  '정상': 3,
#  '예전': 4,
#  '남자친구': 2,
#  '복기': 4,
#  '차단': 3,
#  '풀라': 1,
#  '염탐': 1,
#  '개싫': 1,
#  '기획': 2,
#  '천재': 13,
#  '환장': 3,
#  '딸내미': 6,
#  '무단': 1,
#  '돚거': 1,
#  '숏츠': 1,
#  '창의': 1,
#  '오지': 2,
#  '상처': 1,
#  '모야': 2,
#  '장삐쭈': 2,
#  '스토리텔링': 1,
#  '지렸다': 4,
#  '시간': 34,
#  '가능': 9,
#  '아이': 4,
#  '개웃기네': 7,
#  '구도': 1,
#  '다': 2,
#  '아바': 1,
#  '거지': 3,
#  '하나하나': 1,
#  '연기력': 10,
#  '완성': 2,
#  '목소리': 8,
#  '재밋다': 3,
#  '심장': 7,
#  '쟝르': 1,
#  '호러물': 1,
#  '식은땀': 2,
#  '합리': 1,
#  '종점': 1,
#  '남편': 4,
#  '몰입도': 7,
#  '진지': 2,
#  '충': 5,
#  '모드': 2,
#  '성인': 11,
#  '섹스': 4,
#  '신경': 3,
#  '지랄': 2,
#  '졸': 2,
#  '봄': 3,
#  '가': 1,
#  '싱숨생숨': 1,
#  '수민': 1,
#  '대결': 13,
#  '고딩': 1,
#  '야자': 1,
#  '커플': 4,
#  '현명': 1,
#  '졸잼': 2,
#  '누님': 1,
#  '씬스틸러시네요': 1,
#  '와': 2,
#  '역공': 6,
#  '꿀': 18,
#  '닥달': 1,
#  '임기응변': 4,
#  '큭': 1,
#  '대국': 27,
#  '나중': 7,
#  '동포': 1,
#  '사투리': 1,
#  '존너잼잇억': 1,
#  '기승전결': 10,
#  '술맛': 1,
#  '이혼': 1,
#  '부부': 1,
#  '실화': 5,
#  '스토리': 11,
#  '구성': 8,
#  '배꼽': 5,
#  '틈': 7,
#  '첩보전': 1,
#  '전개': 11,
#  '대화': 12,
#  '스누피': 2,
#  '인형이': 1,
#  '존재': 8,
#  '권위': 3,
#  '아래': 2,
#  '미꾸라지': 1,
#  '기술': 2,
#  '음': 2,
#  '정보전': 1,
#  '협상': 6,
#  '현장': 2,
#  '쿠사리': 1,
#  '능지': 1,
#  '오진': 4,
#  '가슴': 3,
#  '걱정': 6,
#  '압박': 3,
#  '약점': 11,
#  '협박': 3,
#  '강제': 1,
#  '합의': 7,
#  '정신': 1,
#  '출처': 1,
#  '영상미': 5,
#  '웃기네': 7,
#  '짜임': 1,
#  '세가': 1,
#  '교환': 5,
#  '인공': 1,
#  '지능': 1,
#  '감명': 1,
#  '절제': 1,
#  '유쾌': 2,
#  '타선': 3,
#  '찐': 1,
#  '판': 8,
#  '대다네': 1,
#  '칭차네': 1,
#  '종': 13,
#  '방': 3,
#  '어린애': 1,
#  '취급': 2,
#  '다행': 4,
#  '특징': 5,
#  '지리넼': 2,
#  '불신': 1,
#  '늪': 1,
#  '속': 8,
#  '쇼당봄': 1,
#  '인줄': 7,
#  '믿음': 2,
#  '경우': 1,
#  '남녀': 1,
#  '갈등': 1,
#  '유도': 1,
#  '재형': 1,
#  '응원': 15,
#  '역사': 1,
#  '순간': 11,
#  '캡쳐': 5,
#  '통금': 8,
#  '단속': 5,
#  '감당': 1,
#  '독립': 1,
#  '일반인': 3,
#  '몰래카메라': 1,
#  '재밌겎': 1,
#  '아게읏': 1,
#  '호통': 1,
#  '수준': 8,
#  '페이스': 2,
#  '따봉': 1,
#  '이마': 1,
#  '핏줄': 2,
#  '웃갸요': 1,
#  '예기': 1,
#  '따님': 10,
#  '현악': 1,
#  '중주': 1,
#  '버그': 1,
#  '묘수': 5,
#  '밥': 3,
#  '부녀자': 1,
#  '승': 4,
#  '개웃곀': 4,
#  '행인': 1,
#  '가읏김': 1,
#  '편': 11,
#  '포': 2,
#  '직원': 2,
#  '왜곡': 1,
#  '신작': 2,
#  '통제': 2,
#  '이제': 3,
#  '업로드': 7,
#  '군대': 2,
#  '전역': 1,
#  '밤': 2,
#  '주말': 2,
#  '단위': 2,
#  '카톡': 2,
#  '늦개': 1,
#  '기보': 20,
#  '진짴': 6,
#  '필요': 10,
#  '업': 2,
#  '유일': 5,
#  '승리': 6,
#  '컨텐츠': 2,
#  '허수아비': 1,
#  '범': 1,
#  '컥': 3,
#  '내밀엇어야됫느데': 1,
#  '연합': 1,
#  '함': 1,
#  '인연': 1,
#  '졸귘': 1,
#  '첨': 1,
#  '제목': 3,
#  '개욱겨': 1,
#  '이버': 1,
#  '축하': 266,
#  '탄': 2,
#  '오늘': 26,
#  '명언': 1,
#  '막판': 3,
#  '개빡돌': 1,
#  '힘': 5,
#  '기회': 1,
#  '혼신': 1,
#  '심리': 3,
#  '턱': 1,
#  '작가': 2,
#  '쌍수': 1,
#  '결론': 2,
#  '윈': 2,
#  '폭력': 2,
#  '부게': 1,
#  '입맛': 1,
#  '땅': 4,
#  '표절': 1,
#  '보고': 3,
#  '개굴잼': 1,
#  '합정역': 1,
#  '긱스타': 1,
#  '실력': 3,
#  '달성': 10,
#  '흠': 1,
#  '우디르급이네': 1,
#  '여주': 1,
#  '뇌': 1,
#  '위기': 1,
#  '빛': 2,
#  '편집': 12,
#  '몰카': 2,
#  '대타': 1,
#  '개웃겨': 10,
#  '부녀지': 4,
#  '의미': 7,
#  '풉': 1,
#  '였따': 1,
#  '단': 7,
#  '개재미썾': 1,
#  '썸넬': 4,
#  '으라하': 1,
#  '하라하하하하하하라': 1,
#  '만': 1,
#  '담배': 1,
#  '외할아버지': 1,
#  '흡연': 1,
#  '연관': 1,
#  '과장': 2,
#  '화': 10,
#  '참을성': 1,
#  '의지': 1,
#  '들통': 1,
#  '기도': 1,
#  '짜증': 13,
#  '전화기': 6,
#  '너머': 1,
#  '주인공': 3,
#  '대비': 1,
#  '준비': 7,
#  '시나리오': 3,
#  '하앜': 1,
#  '점': 3,
#  '둔수': 1,
#  '쩌시네요': 1,
#  '닮앗어': 1,
#  '네': 2,
#  '긴장감': 16,
#  '쩌네요': 1,
#  '자신': 5,
#  '극혐': 1,
#  '순식': 1,
#  '서사시': 1,
#  '백': 1,
#  '끈': 1,
#  '어택': 1,
#  '주가': 1,
#  '밖': 3,
#  '현실감': 2,
#  '후하후하': 1,
#  '룸': 2,
#  '카페': 2,
#  '장소': 2,
#  '제공': 1,
#  '순': 3,
#  '재미써': 1,
#  '전상협': 1,
#  '닭살': 1,
#  '춘희': 2,
#  '내다춘희': 1,
#  '짜장면': 2,
#  '먹방': 1,
#  '분위기': 1,
#  '교훈': 4,
#  '상호': 1,
#  '확증': 4,
#  '파괴': 4,
#  '억지': 6,
#  '후반': 3,
#  '간섭': 5,
#  '정작': 1,
#  '이거디': 1,
#  '동갑': 1,
#  '후': 15,
#  '중년': 1,
#  '완료': 2,
#  '병': 3,
#  '가스': 2,
#  '라이팅': 2,
#  '실제상황': 2,
#  '가정': 3,
#  '걸레': 1,
#  '집안': 4,
#  '풍비': 1,
#  '박살': 1,
#  '어르신': 2,
#  '밴듴': 1,
#  '승인': 2,
#  '내부': 1,
#  '접근': 1,
#  '비번': 1,
#  '일체': 1,
#  '단편': 6,
#  '쇼츠': 1,
#  '보기': 2,
#  '주행': 7,
#  '답정너': 1,
#  '특유': 2,
#  '색깔': 2,
#  '질문': 2,
#  '퀄': 7,
#  '시작': 12,
#  '최초': 2,
#  '개웃기넼': 13,
#  '키덜트': 1,
#  '고갈': 1,
#  '퀄은': 1,
#  '정성': 1,
#  '딜교': 8,
#  '속도': 9,
#  '긴장': 7,
#  '동안': 9,
#  '정조': 1,
#  '파탄': 1,
#  '탓': 2,
#  '이성': 1,
#  '문제': 3,
#  '능력': 1,
#  '씹': 3,
#  '사업': 2,
#  '와이': 1,
#  '미칰': 2,
#  '정수': 1,
#  '메타': 1,
#  '코메디': 1,
#  '섭외': 3,
#  '촬영': 4,
#  '아영띠': 1,
#  '복': 1,
#  '피부': 1,
#  '미쳤다개재밋음': 1,
#  '개탄탄햐': 1,
#  '생일날': 1,
#  '생일': 1,
#  '동태': 1,
#  '꽃가루': 1,
#  '아시': 1,
#  '설명': 5,
#  '란': 1,
#  '하이텐션': 1,
#  '개우끼네옄': 1,
#  '닦달': 3,
#  '애기': 3,
#  '선택지': 1,
#  '문화': 1,
#  '엔딩': 4,
#  '입': 3,
#  '커여움': 1,
#  '고': 4,
#  '연민': 1,
#  '멜로': 1,
#  '똘레랑스': 1,
#  '동족상잔': 1,
#  '인내천': 1,
#  '사상': 1,
#  '종합': 2,
#  '한국': 2,
#  '경쟁력': 1,
#  '풀': 3,
#  '악셀': 2,
#  '극한': 1,
#  '큐': 10,
#  '큐큐큐큐': 1,
#  '개욱기네': 1,
#  '개소리': 2,
#  '맘': 5,
#  '배째짐': 1,
#  '갠': 1,
#  '쵝오': 5,
#  '퍼거슨': 1,
#  '미쳐따': 1,
#  '개콘': 2,
#  '읍윽': 1,
#  '운전대': 1,
#  '브금': 2,
#  '반전이넹': 1,
#  '출연자': 2,
#  '적극': 1,
#  '추천': 3,
#  '휴': 3,
#  '아진짴': 2,
#  '예쁘시고': 1,
#  '오빠': 1,
#  '으앜': 1,
#  '꾸르잼': 1,
#  '사족': 1,
#  '빌드': 1,
#  '친자': 2,
#  '인증': 2,
#  '순삭': 2,
#  '우': 2,
#  '연기자': 3,
#  '경험': 4,
#  '과거': 2,
#  '피드': 1,
#  '점령': 1,
#  '유명': 2,
#  '조': 2,
#  '동아리': 1,
#  '액션': 2,
#  '허': 1,
#  '갑을': 1,
#  '한마디': 1,
#  '명절': 3,
#  '이지선': 1,
#  '기력': 1,
#  '인기': 2,
#  '꽁트': 3,
#  '개잼있네': 1,
#  '시청자': 2,
#  '재밋게': 1,
#  '편차': 1,
#  '콘': 2,
#  '코빅보': 1,
#  '와우': 6,
#  '인간관계': 1,
#  '회': 1,
#  '숨막효': 1,
#  '지겼지가않네': 1,
#  '코믹체널': 1,
#  '몰두': 1,
#  '박수': 2,
#  '마무리': 6,
#  '게시': 1,
#  '글': 7,
#  '팁': 3,
#  '핸드폰': 3,
#  '연결': 2,
#  ...}

# %%
# vocabs의 단어(key)를 빈도에 따라 내림차순 정렬
# 각 단어를 정렬된 순서에 맞춰 빈도를 mapping하여 새로운 dictionary 생성
dict(zip(
    sorted(vocabs, key=lambda x: vocabs[x], reverse = True),    # vocabs의 key를 빈도에 따라 내림차순 정렬
    sorted(vocabs.values(), reverse = True)                     # vocabs의 값을 내림차순 정렬  
))
# Out:
# {'축하': 266,
#  '영상': 254,
#  '아빠': 196,
#  '딸': 154,
#  '이세돌': 145,
#  '때': 122,
#  '개': 119,
#  '숨': 113,
#  '알파고': 109,
#  '수': 105,
#  '이번': 101,
#  '연기': 99,
#  '수정': 87,
#  '신': 82,
#  '아버지': 81,
#  '낚시': 79,
#  '구독자': 72,
#  '최고': 67,
#  '야채': 66,
#  '아영': 63,
#  '엄마': 62,
#  '마지막': 61,
#  '바둑': 60,
#  '아버님': 56,
#  '뒤': 56,
#  '퀄리티': 56,
#  '부모': 54,
#  '디테일': 52,
#  '잼': 50,
#  '친구': 49,
#  '진짜': 49,
#  '국': 49,
#  '레전드': 48,
#  '너덜트': 48,
#  '급': 47,
#  '반전': 46,
#  '전': 45,
#  '부녀': 44,
#  '신뢰': 42,
#  '역대': 40,
#  '말': 38,
#  '채널': 38,
#  '외박': 37,
#  '사람': 37,
#  '대': 36,
#  '수정이': 36,
#  '박': 36,
#  '구독': 35,
#  '창': 35,
#  '남자': 34,
#  '생각': 34,
#  '시간': 34,
#  '몰입': 33,
#  '감사': 33,
#  '전화': 33,
#  '공감': 33,
#  '집': 33,
#  '소파': 30,
#  '배우': 30,
#  '영화': 30,
#  '대본': 29,
#  '남친': 29,
#  '통화': 29,
#  '티키타카': 27,
#  '대국': 27,
#  '정도': 26,
#  '숏': 26,
#  '오늘': 26,
#  '방패': 25,
#  '역': 25,
#  '앞': 25,
#  '중요': 25,
#  '여자': 24,
#  '박스': 24,
#  '대박': 23,
#  '대사': 23,
#  '지간': 23,
#  '딜': 23,
#  '일': 22,
#  '이름': 22,
#  '자식': 22,
#  '결혼': 22,
#  '낚싯대': 22,
#  '어머니': 22,
#  '나이': 21,
#  '기대': 21,
#  '현실': 21,
#  '세상': 20,
#  '댓글': 20,
#  '기보': 20,
#  '스릴러': 19,
#  '쇼파': 19,
#  '소름': 19,
#  '연출': 19,
#  '재미': 19,
#  '싸움': 19,
#  '상황': 18,
#  '완벽': 18,
#  '유튜브': 18,
#  '꿀': 18,
#  '느낌': 17,
#  '인스타': 17,
#  '소리': 16,
#  '영아': 16,
#  '진심': 16,
#  '부계': 16,
#  '거짓말': 16,
#  '얘기': 16,
#  '바둑판': 16,
#  '긴장감': 16,
#  '의심': 15,
#  '지리': 15,
#  '팔로우': 15,
#  '다음': 15,
#  '처음': 15,
#  '장난': 15,
#  '끝': 15,
#  '응원': 15,
#  '후': 15,
#  '앜': 14,
#  '자체': 14,
#  '구라': 13,
#  '지금': 13,
#  '우정': 13,
#  '건강': 13,
#  '장면': 13,
#  '와중': 13,
#  '천재': 13,
#  '대결': 13,
#  '종': 13,
#  '짜증': 13,
#  '개웃기넼': 13,
#  '형': 13,
#  '사랑': 12,
#  '여행': 12,
#  '피': 12,
#  '아부지': 12,
#  '착각': 12,
#  '조회': 12,
#  '짱': 12,
#  '기분': 12,
#  '내용': 12,
#  '대화': 12,
#  '편집': 12,
#  '시작': 12,
#  '감탄': 12,
#  '고퀄': 12,
#  '역전': 12,
#  '중간': 11,
#  '머리': 11,
#  '여자분': 11,
#  '하루': 11,
#  '조이': 11,
#  '역할': 11,
#  '전환': 11,
#  '강태공': 11,
#  '애': 11,
#  '킹': 11,
#  '성인': 11,
#  '스토리': 11,
#  '전개': 11,
#  '약점': 11,
#  '순간': 11,
#  '편': 11,
#  '누나': 10,
#  '펜션': 10,
#  '급발진': 10,
#  '가짜': 10,
#  '매력': 10,
#  '작품': 10,
#  '광고': 10,
#  '영': 10,
#  '손': 10,
#  '연기력': 10,
#  '기승전결': 10,
#  '따님': 10,
#  '필요': 10,
#  '달성': 10,
#  '개웃겨': 10,
#  '화': 10,
#  '큐': 10,
#  '부분': 10,
#  '이야기': 9,
#  '시집': 9,
#  '언니': 9,
#  '부탁': 9,
#  '아이디어': 9,
#  '폰': 9,
#  '표현': 9,
#  '정': 9,
#  '편의점': 9,
#  '관계': 9,
#  '공방전': 9,
#  '공방': 9,
#  '연애': 9,
#  '명작': 9,
#  '가능': 9,
#  '속도': 9,
#  '동안': 9,
#  '개꿀잼': 9,
#  '로또': 9,
#  '사이': 8,
#  '눈물': 8,
#  '돈': 8,
#  '물': 8,
#  '서로': 8,
#  '극': 8,
#  '마음': 8,
#  '녀': 8,
#  '당근': 8,
#  '개인': 8,
#  '집착': 8,
#  '표정': 8,
#  '포인트': 8,
#  '목소리': 8,
#  '구성': 8,
#  '존재': 8,
#  '판': 8,
#  '속': 8,
#  '통금': 8,
#  '수준': 8,
#  '딜교': 8,
#  '오': 8,
#  '존': 8,
#  '인정': 8,
#  '웃': 8,
#  '버튼': 8,
#  '가즈아': 8,
#  '킬포': 8,
#  '관광': 7,
#  '호흡': 7,
#  '자연': 7,
#  '모습': 7,
#  '공격': 7,
#  '가족': 7,
#  '캐리': 7,
#  '공수': 7,
#  '타협': 7,
#  '이후': 7,
#  '입장': 7,
#  '썸': 7,
#  '이유': 7,
#  '서스펜스': 7,
#  '태세': 7,
#  '병풍': 7,
#  '거래': 7,
#  '위': 7,
#  '개웃기네': 7,
#  '심장': 7,
#  '몰입도': 7,
#  '나중': 7,
#  '틈': 7,
#  '합의': 7,
#  '웃기네': 7,
#  '인줄': 7,
#  '업로드': 7,
#  '의미': 7,
#  '단': 7,
#  '준비': 7,
#  '주행': 7,
#  '퀄': 7,
#  '긴장': 7,
#  '글': 7,
#  '돌파': 7,
#  '골드': 7,
#  '사장': 7,
#  '카드': 7,
#  '확인': 6,
#  '선': 6,
#  '평생': 6,
#  '아내': 6,
#  '외모': 6,
#  '헬스장': 6,
#  '카운터': 6,
#  '보수': 6,
#  '이상': 6,
#  '개그': 6,
#  '말씀': 6,
#  '낮': 6,
#  '감': 6,
#  '시': 6,
#  '기': 6,
#  '유지': 6,
#  '네일': 6,
#  '스트레스': 6,
#  '땀': 6,
#  '눈': 6,
#  '딸내미': 6,
#  '역공': 6,
#  '협상': 6,
#  '걱정': 6,
#  '진짴': 6,
#  '승리': 6,
#  '전화기': 6,
#  '억지': 6,
#  '단편': 6,
#  '와우': 6,
#  '마무리': 6,
#  '이해': 6,
#  '집중': 6,
#  '등장': 6,
#  '센스': 6,
#  '중국집': 6,
#  '드라마': 6,
#  '주': 6,
#  '게임': 6,
#  '얼마': 6,
#  '고증': 6,
#  '흐름': 6,
#  '굿': 6,
#  '위치': 6,
#  '보람': 6,
#  '오랜만': 6,
#  '고정': 6,
#  '짧대': 5,
#  '유투브': 5,
#  '결국': 5,
#  '시대': 5,
#  '말투': 5,
#  '결말': 5,
#  '가평': 5,
#  '키': 5,
#  '갑': 5,
#  '알바': 5,
#  '최근': 5,
#  '마켓': 5,
#  '비밀': 5,
#  '유교': 5,
#  '씨': 5,
#  '경기': 5,
#  '정보': 5,
#  '노': 5,
#  '분': 5,
#  '예술': 5,
#  '암': 5,
#  '설정': 5,
#  '찰떡': 5,
#  '아닠': 5,
#  '발': 5,
#  '재능': 5,
#  '와이프': 5,
#  '저녁': 5,
#  '인형': 5,
#  '충': 5,
#  '실화': 5,
#  '배꼽': 5,
#  '영상미': 5,
#  '교환': 5,
#  '특징': 5,
#  '캡쳐': 5,
#  '단속': 5,
#  '묘수': 5,
#  '유일': 5,
#  '힘': 5,
#  '자신': 5,
#  '간섭': 5,
#  '설명': 5,
#  '맘': 5,
#  '쵝오': 5,
#  '저번': 5,
#  '곳': 5,
#  '여사': 5,
#  '딕 션': 5,
#  '선택': 5,
#  '컨셉': 5,
#  '미래': 5,
#  '원조': 5,
#  '맛': 5,
#  '소재': 5,
#  '얼굴': 5,
#  '용': 5,
#  '실망': 5,
#  '치열': 5,
#  '밑': 5,
#  '리얼': 5,
#  '상': 5,
#  '가치': 5,
#  '상추': 5,
#  '현기증': 5,
#  '딸아이': 4,
#  '마누라': 4,
#  '짓': 4,
#  '딸래미': 4,
#  '낙': 4,
#  '예상': 4,
#  '선물': 4,
#  '방어': 4,
#  '연락': 4,
#  '영통': 4,
#  '아': 4,
#  '알고리즘': 4,
#  '완전': 4,
#  '미': 4,
#  '행복': 4,
#  '부전': 4,
#  '밴드': 4,
#  '이': 4,
#  '자녀': 4,
#  '성장': 4,
#  '줄': 4,
#  '웃곀': 4,
#  '고개': 4,
#  '장가': 4,
#  '옆': 4,
#  '남': 4,
#  '여성분': 4,
#  '강아지': 4,
#  '감정': 4,
#  '성공': 4,
#  '예전': 4,
#  '복기': 4,
#  '지렸다': 4,
#  '아이': 4,
#  '남편': 4,
#  '섹스': 4,
#  '커플': 4,
#  '임기응변': 4,
#  '오진': 4,
#  '다행': 4,
#  '승': 4,
#  '개웃곀': 4,
#  '땅': 4,
#  '부녀지': 4,
#  '썸넬': 4,
#  '교훈': 4,
#  '확증': 4,
#  '파괴': 4,
#  '집안': 4,
#  '촬영': 4,
#  '엔딩': 4,
#  '고': 4,
#  '경험': 4,
#  '매불쇼': 4,
#  '지': 4,
#  '시청': 4,
#  '웃기넼': 4,
#  '무시': 4,
#  '티비': 4,
#  '돌': 4,
#  '떡': 4,
#  '시험': 4,
#  '프로그램': 4,
#  '추카': 4,
#  '전세': 4,
#  '요번': 4,
#  '시리즈': 4,
#  '빌드업': 4,
#  '웃음': 4,
#  '형세': 4,
#  '왕': 4,
#  '눈치': 4,
#  '이입': 4,
#  '추카해요': 4,
#  '초반': 4,
#  '각본': 4,
#  '요즘': 4,
#  '주제': 4,
#  '실시간': 4,
#  '코앞': 4,
#  '애비': 3,
#  '할아버지': 3,
#  '뷰티 인사이드': 3,
#  '나라': 3,
#  '인간': 3,
#  '자막': 3,
#  '한국인': 3,
#  '선생': 3,
#  '연극': 3,
#  '날': 3,
#  '클릭': 3,
#  '최소': 3,
#  '육성': 3,
#  '재밋네': 3,
#  '안': 3,
#  '롤': 3,
#  '여친': 3,
#  '스피커': 3,
#  '교대': 3,
#  '엌': 3,
#  '왤캐': 3,
#  '최선': 3,
#  '살': 3,
#  '화이팅': 3,
#  '비서': 3,
#  '어머님': 3,
#  '언급': 3,
#  '두뇌': 3,
#  '달마': 3,
#  '시안': 3,
#  '중독': 3,
#  '하이퍼': 3,
#  '리얼리즘': 3,
#  '후회': 3,
#  '여': 3,
#  '인생': 3,
#  '약속': 3,
#  '장첸': 3,
#  '스타일': 3,
#  '음악': 3,
#  '옛날': 3,
#  '동생': 3,
#  '준팍': 3,
#  '정상': 3,
#  '차단': 3,
#  '환장': 3,
#  '거지': 3,
#  '재밋다': 3,
#  '신경': 3,
#  '봄': 3,
#  '권위': 3,
#  '가슴': 3,
#  '압박': 3,
#  '협박': 3,
#  '타선': 3,
#  '방': 3,
#  '일반인': 3,
#  '밥': 3,
#  '이제': 3,
#  '컥': 3,
#  '제목': 3,
#  '막판': 3,
#  '심리': 3,
#  '보고': 3,
#  '실력': 3,
#  '주인공': 3,
#  '시나리오': 3,
#  '점': 3,
#  '밖': 3,
#  '순': 3,
#  '후반': 3,
#  '병': 3,
#  '가정': 3,
#  '문제': 3,
#  '씹': 3,
#  '섭외': 3,
#  '닦달': 3,
#  '애기': 3,
#  '입': 3,
#  '풀': 3,
#  '추천': 3,
#  '휴': 3,
#  '연기자': 3,
#  '명절': 3,
#  '꽁트': 3,
#  '팁': 3,
#  '핸드폰': 3,
#  '유사': 3,
#  '제일': 3,
#  '협': 3,
#  '우울': 3,
#  '노력': 3,
#  '오해': 3,
#  '대신': 3,
#  '거짓': 3,
#  '추억': 3,
#  '특': 3,
#  '한참': 3,
#  '견과': 3,
#  '사랑해요': 3,
#  '야채좌': 3,
#  '기획력': 3,
#  '선수': 3,
#  '톤': 3,
#  '미안': 3,
#  '고생': 3,
#  '여직원': 3,
#  '차': 3,
#  '개쩌': 3,
#  '대학': 3,
#  '개쩐': 3,
#  '텐': 3,
#  '템포': 3,
#  '복선': 3,
#  '전차': 3,
#  '외통수': 3,
#  '개웃': 3,
#  '무료': 3,
#  '핑계': 3,
#  '욕': 3,
#  '조아': 3,
#  '무비': 3,
#  '귀': 3,
#  '레알': 3,
#  '아놔': 3,
#  '잠': 3,
#  '배': 3,
#  '걸': 3,
#  '기념': 3,
#  '방귀': 3,
#  '감독': 3,
#  '화면': 3,
#  '아들': 3,
#  '재밋': 3,
#  '유튜버': 3,
#  '혼자': 3,
#  '다이아몬드': 3,
#  '우선': 3,
#  '절대': 3,
#  '사': 3,
#  '원': 3,
#  '빈틈': 3,
#  '갓덜트': 3,
#  '영원': 3,
#  '생수': 3,
#  '세뇌': 2,
#  '좀비': 2,
#  '대역': 2,
#  '기업': 2,
#  '캐나다': 2,
#  '손주': 2,
#  '사실': 2,
#  '본인': 2,
#  '골프채': 2,
#  '야스오': 2,
#  '영어': 2,
#  '필수': 2,
#  '차별': 2,
#  '기준': 2,
#  '오마주': 2,
#  '멸망': 2,
#  '고민': 2,
#  '칼': 2,
#  '분노': 2,
#  '조절': 2,
#  '건': 2,
#  '치킨': 2,
#  '새벽': 2,
#  '반복': 2,
#  '포기': 2,
#  '개쩌네': 2,
#  '신세계': 2,
#  '나': 2,
#  '아저씨': 2,
#  '사진': 2,
#  '전국': 2,
#  '구': 2,
#  '안녕': 2,
#  '당시': 2,
#  '발음': 2,
#  '시점': 2,
#  '깨알': 2,
#  '킬': 2,
#  '진실': 2,
#  '드립': 2,
#  '면': 2,
#  '역습': 2,
#  '적령기': 2,
#  '초중반': 2,
#  '여자친구': 2,
#  '강사': 2,
#  '프리미엄': 2,
#  '속초': 2,
#  '잔': 2,
#  '퐁고': 2,
#  '피곤': 2,
#  '왘': 2,
#  '너털트': 2,
#  '요새': 2,
#  '대세': 2,
#  '램': 2,
#  '방생': 2,
#  '뷰': 2,
#  '손자': 2,
#  '타이밍': 2,
#  '동호회': 2,
#  '여기저기': 2,
#  '주인': 2,
#  '최지우': 2,
#  '연출력': 2,
#  '기억': 2,
#  '산': 2,
#  '교': 2,
#  '결과': 2,
#  '남자친구': 2,
#  '기획': 2,
#  '오지': 2,
#  '모야': 2,
#  '장삐쭈': 2,
#  '다': 2,
#  '완성': 2,
#  '식은땀': 2,
#  '진지': 2,
#  '모드': 2,
#  '지랄': 2,
#  '졸': 2,
#  '졸잼': 2,
#  '와': 2,
#  '스누피': 2,
#  '아래': 2,
#  '기술': 2,
#  '음': 2,
#  '현장': 2,
#  '유쾌': 2,
#  '취급': 2,
#  '지리넼': 2,
#  '믿음': 2,
#  '페이스': 2,
#  '핏줄': 2,
#  '포': 2,
#  '직원': 2,
#  '신작': 2,
#  '통제': 2,
#  '군대': 2,
#  '밤': 2,
#  '주말': 2,
#  '단위': 2,
#  '카톡': 2,
#  '업': 2,
#  '컨텐츠': 2,
#  '탄': 2,
#  '작가': 2,
#  '결론': 2,
#  '윈': 2,
#  '폭력': 2,
#  '빛': 2,
#  '몰카': 2,
#  '과장': 2,
#  '네': 2,
#  '현실감': 2,
#  '룸': 2,
#  '카페': 2,
#  '장소': 2,
#  '춘희': 2,
#  '짜장면': 2,
#  '완료': 2,
#  '가스': 2,
#  '라이팅': 2,
#  '실제상황': 2,
#  '어르신': 2,
#  '승인': 2,
#  '보기': 2,
#  '특유': 2,
#  '색깔': 2,
#  '질문': 2,
#  '최초': 2,
#  '탓': 2,
#  '사업': 2,
#  '미칰': 2,
#  '종합': 2,
#  '한국': 2,
#  '악셀': 2,
#  '개소리': 2,
#  '개콘': 2,
#  '브금': 2,
#  '출연자': 2,
#  '아진짴': 2,
#  '친자': 2,
#  '인증': 2,
#  '순삭': 2,
#  '우': 2,
#  '과거': 2,
#  '유명': 2,
#  '조': 2,
#  '액션': 2,
#  '인기': 2,
#  '시청자': 2,
#  '콘': 2,
#  '박수': 2,
#  '연결': 2,
#  '손해': 2,
#  '쩌네': 2,
#  '전상': 2,
#  '새끼': 2,
#  '오랫만': 2,
#  '주문': 2,
#  '반응': 2,
#  '출연': 2,
#  '이것저것': 2,
#  '물체': 2,
#  '방해': 2,
#  '프로': 2,
#  '퀄러티': 2,
#  '보소': 2,
#  '재현': 2,
#  '인류': 2,
#  '순발력': 2,
#  '손가락': 2,
#  '간': 2,
#  '반영': 2,
#  '완성도': 2,
#  '량': 2,
#  '새': 2,
#  '장편': 2,
#  '블록버스터': 2,
#  '덕분': 2,
#  '용납': 2,
#  '마음가짐': 2,
#  '자격': 2,
#  '반': 2,
#  '승승장구': 2,
#  '동영상': 2,
#  '씬': 2,
#  '배경': 2,
#  '상상': 2,
#  '플레이': 2,
#  '하드캐리': 2,
#  '관계자': 2,
#  '경쟁': 2,
#  '불편': 2,
#  '한': 2,
#  '혼전': 2,
#  '순결': 2,
#  '흑': 2,
#  '상대': 2,
#  '삼성': 2,
#  '모양': 2,
#  '팩트': 2,
#  '하': 2,
#  '민': 2,
#  '세대': 2,
#  '끝판왕': 2,
#  '오지네': 2,
#  '당': 2,
#  '감동': 2,
#  '코믹': 2,
#  '거울': 2,
#  '테이블': 2,
#  '세계관': 2,
#  '최강': 2,
#  '짜임새': 2,
#  '커피': 2,
#  '스릴': 2,
#  '여유': 2,
#  '기본': 2,
#  '긴박': 2,
#  '개쩐다': 2,
#  '지향': 2,
#  '루즈': 2,
#  '평론가': 2,
#  '바둑알': 2,
#  '공포': 2,
#  '데스크': 2,
#  '코미디': 2,
#  '초심': 2,
#  '아침': 2,
#  '버전': 2,
#  '부전자전': 2,
#  '대다수': 2,
#  '아드님': 2,
#  '우왕': 2,
#  '진자': 2,
#  '제작': 2,
#  '보답': 2,
#  '쌉': 2,
#  '콩': 2,
#  '윈윈': 2,
#  '보': 2,
#  '정상급': 2,
#  '고수': 2,
#  '김': 2,
#  '왤': 2,
#  '꼰대': 2,
#  '등가교환': 2,
#  '수가': 2,
#  '쩌러': 2,
#  '계정': 2,
#  '공부': 2,
#  '유튭': 2,
#  '대답': 2,
#  '능청': 2,
#  '장난감': 2,
#  '항상': 2,
#  '시바': 2,
#  '부족': 2,
#  '버스': 2,
#  '기사': 2,
#  '각': 2,
#  '만족': 2,
#  '썰': 2,
#  '계기': 2,
#  '뉴스': 2,
#  '이실직고': 2,
#  '결정타': 2,
#  '근래': 2,
#  '비교': 2,
#  '알림': 2,
#  '이전': 2,
#  '개재밌네': 2,
#  '초딩': 2,
#  '상태': 2,
#  '핵': 2,
#  '뇌리': 2,
#  '개그맨': 2,
#  '차원': 2,
#  '감상': 2,
#  '남자분': 2,
#  '공중파': 2,
#  '넘버원': 2,
#  '처녀': 2,
#  '선정': 2,
#  '이미지': 2,
#  '누더기': 2,
#  '패': 2,
#  '행': 2,
#  '꺅': 2,
#  '식스 센스': 2,
#  '콜라': 2,
#  '일주일': 2,
#  '팬': 2,
#  '물건': 2,
#  '제보': 2,
#  '열': 2,
#  '총': 2,
#  '구멍': 2,
#  '방송': 2,
#  '난': 2,
#  '경찰': 2,
#  '파': 2,
#  '당첨': 2,
#  '평소': 2,
#  '참고': 2,
#  '한수': 2,
#  '속도감': 2,
#  '맛집': 2,
#  '미끼': 2,
#  '변화': 2,
#  '뜻': 2,
#  '꼼수': 2,
#  '고급': 2,
#  '민주': 2,
#  '쫄리지': 2,
#  '올': 2,
#  '현규': 2,
#  '규': 2,
#  '문지방': 2,
#  '시트콤': 2,
#  '따': 2,
#  '탑': 2,
#  '철저': 2,
#  '반격': 2,
#  '너들트': 2,
#  '영상퀄': 2,
#  '필터': 2,
#  '반성': 2,
#  '장르': 2,
#  '백미': 2,
#  '승부': 2,
#  '애인': 2,
#  '웰': 2,
#  '상징': 2,
#  '조선족': 2,
#  '깔끔': 2,
#  '방금': 2,
#  '존나재밋': 2,
#  '보청기': 2,
#  '신청': 2,
#  '함정': 2,
#  '각자': 2,
#  '편도': 2,
#  '캐릭터': 2,
#  '아이디': 2,
#  '시전': 2,
#  '여성': 2,
#  '귀여워': 1,
#  '장모': 1,
#  '장인': 1,
#  '상기': 1,
#  '진전': 1,
#  '사위': 1,
#  '타임': 1,
#  '장려': 1,
#  '죈장': 1,
#  '양육': 1,
#  '신데렐라': 1,
#  '놀이': 1,
#  '먹버': 1,
#  '아귀': 1,
#  '평균': 1,
#  '고봉': 1,
#  '반추': 1,
#  '인위': 1,
#  '디스거네': 1,
#  '낚시대': 1,
#  '서': 1,
#  '네야': 1,
#  '사회': 1,
#  '생활': 1,
#  '엿': 1,
#  '이부뷴': 1,
#  '현': 1,
#  '쌉캐리네': 1,
#  '시야': 1,
#  '거절': 1,
#  '처다': 1,
#  '경고': 1,
#  '메시지': 1,
#  '답': 1,
#  '앀': 1,
#  '현웃': 1,
#  '애애애애': 1,
#  '레웃기네': 1,
#  '발전': 1,
#  '나머지': 1,
#  '최곸': 1,
#  '소거': 1,
#  '기능': 1,
#  '동종': 1,
#  '업계': 1,
#  '괴성': 1,
#  '값': 1,
#  ...}

# %%
words = np.array(words)
words = np.where((words == '아버지') | (words == '아버님'), '아빠', words)
words = np.where(words == '수정', '수정이', words)

# %%
counter = Counter(words)

# %%
counter.pop('때')
counter.pop('수')
counter.pop('신')
counter.pop('뒤')
counter.pop('개')
counter.pop('숨')
counter.pop('역')
# Out:
# 25

# %%
counter.pop('축하')
counter.pop('영상')
counter.pop('이번')
counter.pop('정도')
# Out:
# 26

# %%
word_cloud = WordCloud(
    font_path = 'malgun',
    background_color = 'white',
    max_font_size = 100,
    colormap = 'prism',
).generate_from_frequencies(counter)

plt.figure(figsize=(10, 8))
plt.imshow(word_cloud)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %% [markdown]
# #### 유튜브 댓글 분석 - 곽튜브

# %%
kwak = pd.read_pickle('./data/NLP/comments_kwak.pickle')
kwak
# Out:
#                      channelId      videoId parentID  \
# 0     UClRNDVO8093rmRTtLe4GEPw  1IlOwJtyE7Q
# 1     UClRNDVO8093rmRTtLe4GEPw  1IlOwJtyE7Q
# 2     UClRNDVO8093rmRTtLe4GEPw  1IlOwJtyE7Q
# 3     UClRNDVO8093rmRTtLe4GEPw  1IlOwJtyE7Q
# 4     UClRNDVO8093rmRTtLe4GEPw  1IlOwJtyE7Q
# ...                        ...          ...      ...
# 5100  UClRNDVO8093rmRTtLe4GEPw  1IlOwJtyE7Q      NaN
# 5101  UClRNDVO8093rmRTtLe4GEPw  1IlOwJtyE7Q      NaN
# 5102  UClRNDVO8093rmRTtLe4GEPw  1IlOwJtyE7Q      NaN
# 5103  UClRNDVO8093rmRTtLe4GEPw  1IlOwJtyE7Q      NaN
# 5104  UClRNDVO8093rmRTtLe4GEPw  1IlOwJtyE7Q      NaN
#
#                                             textDisplay  \
# 0                                   곽튜브 힘내시라!  항상 응원할게~
# 1                                              동싱아 잘있나?
# 2                                             형 돌아와요!!!
# 3        언제 새 동영상 볼수있는거임. 기다리고있음. 항상 응원. 그럴 사람 아니란거 아니까
# 4                                아니 이쁘면 무죈데 왤캐 선비들이 많음?
# ...                                                 ...
# 5100                       @@trumpdonald6781질투하누 ㅋㅎㅋㅎㅋㅎ
# 5101                                                  ㅐ
# 5102                              축하해요... 덕포동의 자랑!! 곽튜브
# 5103  <a href="https://www.youtube.com/watch?v=1IlOw...
# 5104  @@trumpdonald6781 당사자들은 그런 사이가 아닐 수도 있는데(심지어 한...
#
#                                            textOriginal authorDisplayName  \
# 0                                   곽튜브 힘내시라!  항상 응원할게~      @junobox7004
# 1                                              동싱아 잘있나?  @user-rz7mn4gx2c
# 2                                             형 돌아와요!!!             @무징징이
# 3        언제 새 동영상 볼수있는거임. 기다리고있음. 항상 응원. 그럴 사람 아니란거 아니까    @usangjung7865
# 4                                아니 이쁘면 무죈데 왤캐 선비들이 많음?      @1a2a3a4a5aa
# ...                                                 ...               ...
# 5100                       @@trumpdonald6781질투하누 ㅋㅎㅋㅎㅋㅎ       @Yoon____90
# 5101                                                  ㅐ  @user-xn6id7pp4s
# 5102                              축하해요... 덕포동의 자랑!! 곽튜브            @포장의마법
# 5103     14:00 딱봐도 불편해하는데 사장이라 뭔 말도 못하겠고 직원들이 밑이네 확실히ㅋㅋ  @trumpdonald6781
# 5104  @@trumpdonald6781 당사자들은 그런 사이가 아닐 수도 있는데(심지어 한...          @김라마-p6v
#
#       likeCount           publishedAt             updatedAt  \
# 0             1  2024-10-04T01:20:38Z  2024-10-04T01:20:38Z
# 1             4  2024-10-04T00:23:53Z  2024-10-04T00:23:53Z
# 2             5  2024-10-04T00:09:08Z  2024-10-04T00:09:08Z
# 3             4  2024-10-04T00:07:30Z  2024-10-04T00:07:30Z
# 4             2  2024-10-03T23:42:27Z  2024-10-03T23:42:27Z
# ...         ...                   ...                   ...
# 5100         12  2024-08-30T12:24:10Z  2024-08-30T12:24:10Z
# 5101          0  2024-08-30T12:53:06Z  2024-08-30T12:53:06Z
# 5102          3  2024-08-30T12:13:53Z  2024-08-30T12:13:53Z
# 5103          0  2024-08-30T12:23:48Z  2024-08-30T12:23:48Z
# 5104          1  2024-08-30T12:45:16Z  2024-08-30T14:33:48Z
#
#                         parentId
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 5100  Ugx-p0gVXHlBTszw53x4AaABAg
# 5101  Ugx-p0gVXHlBTszw53x4AaABAg
# 5102  UgynyiSumZLL457W9eJ4AaABAg
# 5103  Ugwf8kyQ4HNz4t5CVEB4AaABAg
# 5104  Ugwf8kyQ4HNz4t5CVEB4AaABAg
#
# [18825 rows x 10 columns]

# %%
# Kiwi 객체를 생성
kiwi = Kiwi()

# 'kiwi_tokenizer' function
# 'contents': 입력 텍스트, 'Stopwords': 불용어 목록 (optional)
def kiwi_tokenizer(contents, stopwords=None):

    # 'contents'를 Kiwi 객체로 tokenize(단어 분리)하고, 명사(NNP, NNG)만 추출
    tokens = [
        token.form                                          # 각 token의 형태소 반환 (단어 자체)
        for token
        in kiwi.tokenize(contents, stopwords=stopwords)     # Kiwi 객체로 tokenize 실행
        if token.tag in {'NNP', 'NNG'}                      # 추출된 token이 NNP(고유명사) 혹은 NNG(일반명사)일 경우만 핉터링
    ]

    # 최종적으로 명사들로만 구성된 리스트 반환
    return tokens

# %%
kiwi = Kiwi()
kiwi.add_user_word('곽튜브', 'NNP')
kiwi.add_user_word('학폭', 'NNG's\)
kiwi.add_user_word('곽튜브', 'NNP')

# %%
stopwords = Stopwords()
stopwords

# %%
kwak['tokens'] = kwak.textOriginal.apply(lambda x: kiwi_tokenizer(x))
counter = Counter(list(itertools.chain(*kwak.tokens)))

# %%
counter.pop('노무현')
counter.pop('컴퍼니')
# Out:
# 263

# %%
word_cloud = WordCloud(
    font_path='malgun',
    background_color='black',
    max_font_size=100,
    colormap='prism',
).generate_from_frequencies(counter)

plt.figure(figsize=(10, 8))
plt.imshow(word_cloud)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))
